# %%
import re
import os
from config.config_loader import load_config
import numpy as np
import pandas as pd
from datetime import timedelta
import datetime
from scipy.stats import skew, kurtosis, iqr
import multiprocessing
from joblib import Parallel, delayed
import matplotlib.pyplot as plt
# 获取基本配置信息
CONFIG_DATA = load_config(os.path.join("config", "feature_engineering_config.json"))
WINDOW_SIZE_S = CONFIG_DATA["sliding_window_settings"]["window_size_s"]
PEDAL_SAMPLE_RATE_HZ = CONFIG_DATA["pedal_hz"]
STEP_SIZE_S = CONFIG_DATA["sliding_window_settings"]["step_size_s"]

# %%
 #找到起始索引的工具函数
def change_index(input_index,df,start_timestamp):  
    
    # 计算阈值
    threshold = start_timestamp + input_index
    
    # 使用布尔索引获取符合条件的行
    filtered_df = df[df['timestamp'] > threshold]
    
    # 获取第一个符合条件的索引
    first_index = filtered_df.index[0] if not filtered_df.empty else None
    return first_index

# %% [markdown]
# ## 这里whole是整段切片

# %%
def concat_df(df,person_type,person_num,data_type,ex_name):
    NC_highway_straight = [
                            [["1:38","2:07"],["2:40","2:42"],["2:48","3:14"],["3:35","3:59"],["4:07","5:18"],["6:05","6:20"],["8:50","9:34"],["9:59","10:15"]],  # NC1
                            [["2:56","3:08"],["3:36","3:51"],["4:21","4:30"],["4:51","8:31"],["10:26","10:41"],["11:06","11:30"]],  # NC2
                            [["2:47","2:52"],["2:58","3:27"],["3:53","4:30"],["5:24","6:44"],["6:47","7:33"]],  # NC3
                            [["2:01","2:05"],["2:35","3:04"],["3:37","3:40"],["3:48","5:27"],["5:56","6:39"],["7:19","7:33"],["7:46","8:07"],["8:53","9:13"]],  # NC4
                            [["1:38","2:01"],["2:30","2:57"],["3:20","5:23"],["5:28","5:52"],["6:28","6:48"],["11:00","11:14"],["11:36","12:00"]],  # NC5
                            [["1:13","1:30"],["1:50","2:07"],["2:40","3:33"],["3:40","4:20"],["4:30","4:50"],["5:00","5:50"],["5:59","6:15"],["6:35","6:56"],["9:50","10:20"],["10:56","11:13"]],  # NC6
                            [["1:13","1:39"],["1:53","2:10"],["2:46","3:29"],["3:49","5:56"],["6:28","7:30"],["7:51","8:13"]],  # NC7
                            [["1:40","2:07"],["3:19","4:20"],["4:35","4:48"],["5:10","7:14"],["7:20","7:42"],["8:04","8:39"]],  # NC8
                            [["1:37","2:06"],["3:10","4:42"],["4:49","6:09"],["6:39","6:50"],["7:16","7:26"],["9:31","9:53"],["10:20","10:40"],["11:10","11:35"]],  # NC9
                            [["3:22","3:57"],["4:39","7:27"],["7:58","9:50"]],  # NC10
                            [["2:11","2:16"],["2:23","2:38"],["3:09","5:09"],["6:40","7:06"],["7:34","7:44"],["9:23","9:41"]],  # NC11
                            [["1:10","1:40"],["2:07","5:41"],["6:13","6:32"],["7:59","8:18"],["8:38","9:04"],["9:44","10:19"]],  # NC12
                            [["1:33","1:59"],["2:38","5:38"],["7:19","7:41"],["8:03","8:23"],["10:53","11:09"]],  # NC13
                    [["1:50","15:22"]],[["1:32","15:52"]],[["3:17","17:23"]],#NC24
                    [["2:20","16:02"]], #NC25
                    [["3:22","17:10"]],[["1:33","17:49"]],[["4:04","15:29"]],#NC28
                    [["1:32","15:26"]],[["3:04","15:34"]],[["2:01","15:34"]]#NC31
                   ]

    if person_type =="PD":
        start_timestamp = CONFIG_DATA["PD_data_path"]["video_start_timestamp_"+ex_name][person_num]
        if data_type == "straight":
            time_slice = PD_highway_straight
        elif data_type == "turn":
            time_slice = PD_highway_turn
        elif ex_name =="ex2":    
            time_slice = Whole_slice_PD_highway
        else:
            time_slice = Whole_slice_PD_city
    else:
        start_timestamp = CONFIG_DATA["NC_data_path"]["video_start_timestamp_"+ex_name][person_num]
        if data_type == "straight":
            time_slice = NC_highway_straight
        elif data_type == "turn":
            time_slice = NC_highway_turn
        elif ex_name =="ex2":    
            time_slice = Whole_slice_NC_highway
        else:
            time_slice =Whole_slice_NC_city
    
    df_subset = pd.DataFrame()
    total_time = 0

    for times in time_slice[person_num]:
        start_time = int(times[0].split(":")[0])*60+int(times[0].split(":")[1])
        end_time = int(times[1].split(":")[0])*60+int(times[1].split(":")[1])
        start_index = change_index(start_time, df, start_timestamp)
        end_index = change_index(end_time, df, start_timestamp)
        print("Trying to slice: ", start_index, end_index)

        df_subset = pd.concat([df_subset,df.iloc[start_index:end_index].copy()],axis= 0, ignore_index=True)
        
    return df_subset

# %% [markdown]
# ## 只切study2 直线

# %%
# import os
# import pandas as pd
# from config.config_loader import load_config

# CONFIG_DATA = load_config(os.path.join("config", "feature_engineering_config.json"))
# NC_number = CONFIG_DATA["NC_number"]
# PD_number = CONFIG_DATA["PD_number"]

# # === 读取PD组 ===
# PD_pedal_data_ex2 = pd.read_csv('data_pro1/PD_pedal_data_ex2.csv')
# PD_speed_data_ex2 = pd.read_csv('data_pro1/PD_speed_data_ex2.csv')
# PD_eyemovement_data_ex2 = pd.read_csv('data_pro1/PD_eyemovement_data_ex2.csv')

# # === 读取NC组 ===
# NC_pedal_data_ex2 = pd.read_csv('data_pro1/NC_pedal_data_ex2.csv')
# NC_speed_data_ex2 = pd.read_csv('data_pro1/NC_speed_data_ex2.csv')
# NC_eyemovement_data_ex2 = pd.read_csv('data_pro1/NC_eyemovement_data_ex2.csv')

# PD_data_dict = {
#     "pedal_ex2": PD_pedal_data_ex2,
#     "speed_ex2": PD_speed_data_ex2,
#     "eyemovement_ex2": PD_eyemovement_data_ex2,
# }

# NC_data_dict = {
#     "pedal_ex2": NC_pedal_data_ex2,
#     "speed_ex2": NC_speed_data_ex2,
#     "eyemovement_ex2": NC_eyemovement_data_ex2,
# }

# #为PD的ex2的三个数据文件切片
# for person_num in range(PD_number):  
#     # 对每种数据类型进行处理
#     for type in ["pedal", "speed", "eyemovement"]:
#         for ex in ["ex2"]:
#             for data_type in ["straight"]:
#                 # 动态获取相应的数据集
#                 big_df = PD_data_dict[type+"_"+ex]
                
#                 # 根据person_id筛出当前这个人
#                 df = big_df[big_df['person_id'] == person_num + 1].copy().reset_index(drop=True)

#                 # 调用concat_df进行数据切片处理
                
#                 df_subset = concat_df(df, "PD", person_num, data_type,ex)
                
#                 # 构建保存文件的路径
#                 output_dir = f"./sliced_data/PD/PD{person_num + 1}"
                
#                 # 确保目标路径存在
#                 os.makedirs(output_dir, exist_ok=True)
                
#                 # 保存文件
#                 file_path = f"{output_dir}/{data_type}_{type+"_"+ex}.csv"
#                 df_subset.to_csv(file_path, index=False)
#                 print(f"over {person_num + 1} - {type+"_"+ex} - {data_type}")


# for person_num in range(NC_number):  
#     # 对每种数据类型进行处理
#     for type in ["pedal", "speed", "eyemovement"]:
#         for ex in ["ex2"]:
#             for data_type in ["straight"]:
#                 # 动态获取相应的数据集
#                 big_df = NC_data_dict[type+"_"+ex]
                
#                 # 根据person_id筛出当前这个人
#                 df = big_df[big_df['person_id'] == person_num + 1].copy().reset_index(drop=True)
                
#                 # 调用concat_df进行数据切片处理
#                 df_subset = concat_df(df, "NC", person_num, data_type,ex)
                
#                 # 构建保存文件的路径
#                 output_dir = f"./sliced_data/NC/NC{person_num + 1}"
                
#                 # 确保目标路径存在
#                 os.makedirs(output_dir, exist_ok=True)
                
#                 # 保存文件
#                 file_path = f"{output_dir}/{data_type}_{type+"_"+ex}.csv"
#                 df_subset.to_csv(file_path, index=False)
#                 print(f"over {person_num + 1} - {type+"_"+ex} - {data_type}")

# %% [markdown]
# ## 弯道

# %%
# import os
# import pandas as pd
# from config.config_loader import load_config

# CONFIG_DATA = load_config(os.path.join("config", "feature_engineering_config.json"))
# NC_number = CONFIG_DATA["NC_number"]
# PD_number = CONFIG_DATA["PD_number"]

# # === 读取PD组 ===
# PD_pedal_data_ex2 = pd.read_csv('data_pro1/PD_pedal_data_ex2.csv')
# PD_speed_data_ex2 = pd.read_csv('data_pro1/PD_speed_data_ex2.csv')
# PD_eyemovement_data_ex2 = pd.read_csv('data_pro1/PD_eyemovement_data_ex2.csv')

# # === 读取NC组 ===
# NC_pedal_data_ex2 = pd.read_csv('data_pro1/NC_pedal_data_ex2.csv')
# NC_speed_data_ex2 = pd.read_csv('data_pro1/NC_speed_data_ex2.csv')
# NC_eyemovement_data_ex2 = pd.read_csv('data_pro1/NC_eyemovement_data_ex2.csv')

# PD_data_dict = {
#     "pedal_ex2": PD_pedal_data_ex2,
#     "speed_ex2": PD_speed_data_ex2,
#     "eyemovement_ex2": PD_eyemovement_data_ex2,
# }

# NC_data_dict = {
#     "pedal_ex2": NC_pedal_data_ex2,
#     "speed_ex2": NC_speed_data_ex2,
#     "eyemovement_ex2": NC_eyemovement_data_ex2,
# }

# #为PD的ex2的三个数据文件切片
# for person_num in range(PD_number):  
#     # 对每种数据类型进行处理
#     for type in ["pedal", "speed", "eyemovement"]:
#         for ex in ["ex2"]:
#             for data_type in ["turn"]:
#                 # 动态获取相应的数据集
#                 big_df = PD_data_dict[type+"_"+ex]
                
#                 # 根据person_id筛出当前这个人
#                 df = big_df[big_df['person_id'] == person_num + 1].copy().reset_index(drop=True)

#                 # 调用concat_df进行数据切片处理
                
#                 df_subset = concat_df(df, "PD", person_num, data_type,ex)
                
#                 # 构建保存文件的路径
#                 output_dir = f"./sliced_data/PD/PD{person_num + 1}"
                
#                 # 确保目标路径存在
#                 os.makedirs(output_dir, exist_ok=True)
                
#                 # 保存文件
#                 file_path = f"{output_dir}/{data_type}_{type+"_"+ex}.csv"
#                 df_subset.to_csv(file_path, index=False)
#                 print(f"over {person_num + 1} - {type+"_"+ex} - {data_type}")


# for person_num in range(NC_number):  
#     # 对每种数据类型进行处理
#     for type in ["pedal", "speed", "eyemovement"]:
#         for ex in ["ex2"]:
#             for data_type in ["turn"]:
#                 # 动态获取相应的数据集
#                 big_df = NC_data_dict[type+"_"+ex]
                
#                 # 根据person_id筛出当前这个人
#                 df = big_df[big_df['person_id'] == person_num + 1].copy().reset_index(drop=True)
                
#                 # 调用concat_df进行数据切片处理
#                 df_subset = concat_df(df, "NC", person_num, data_type,ex)
                
#                 # 构建保存文件的路径
#                 output_dir = f"./sliced_data/NC/NC{person_num + 1}"
                
#                 # 确保目标路径存在
#                 os.makedirs(output_dir, exist_ok=True)
                
#                 # 保存文件
#                 file_path = f"{output_dir}/{data_type}_{type+"_"+ex}.csv"
#                 df_subset.to_csv(file_path, index=False)
#                 print(f"over {person_num + 1} - {type+"_"+ex} - {data_type}")

# %% [markdown]
# ## 整段切片

# %%
# import os
# import pandas as pd
# from config.config_loader import load_config

# CONFIG_DATA = load_config(os.path.join("config", "feature_engineering_config.json"))
# NC_number = CONFIG_DATA["NC_number"]
# PD_number = CONFIG_DATA["PD_number"]

# # === 读取PD组 ===
# PD_pedal_data_ex1 = pd.read_csv('data_pro1/PD_pedal_data_ex1.csv')
# PD_speed_data_ex1 = pd.read_csv('data_pro1/PD_speed_data_ex1.csv')
# PD_eyemovement_data_ex1 = pd.read_csv('data_pro1/PD_eyemovement_data_ex1.csv')

# PD_pedal_data_ex2 = pd.read_csv('data_pro1/PD_pedal_data_ex2.csv')
# PD_speed_data_ex2 = pd.read_csv('data_pro1/PD_speed_data_ex2.csv')
# PD_eyemovement_data_ex2 = pd.read_csv('data_pro1/PD_eyemovement_data_ex2.csv')

# # PD_pedal_data_ex3 = pd.read_csv('data_pro1/PD_pedal_data_ex3.csv')
# # PD_speed_data_ex3 = pd.read_csv('data_pro1/PD_speed_data_ex3.csv')
# # PD_eyemovement_data_ex3 = pd.read_csv('data_pro1/PD_eyemovement_data_ex3.csv')

# # === 读取NC组 ===
# NC_pedal_data_ex1 = pd.read_csv('data_pro1/NC_pedal_data_ex1.csv')
# NC_speed_data_ex1 = pd.read_csv('data_pro1/NC_speed_data_ex1.csv')
# NC_eyemovement_data_ex1 = pd.read_csv('data_pro1/NC_eyemovement_data_ex1.csv')

# NC_pedal_data_ex2 = pd.read_csv('data_pro1/NC_pedal_data_ex2.csv')
# NC_speed_data_ex2 = pd.read_csv('data_pro1/NC_speed_data_ex2.csv')
# NC_eyemovement_data_ex2 = pd.read_csv('data_pro1/NC_eyemovement_data_ex2.csv')

# # NC_pedal_data_ex3 = pd.read_csv('data_pro1/NC_pedal_data_ex3.csv')
# # NC_speed_data_ex3 = pd.read_csv('data_pro1/NC_speed_data_ex3.csv')
# # NC_eyemovement_data_ex3 = pd.read_csv('data_pro1/NC_eyemovement_data_ex3.csv')

# PD_data_dict = {
#     "pedal_ex1": PD_pedal_data_ex1,
#     "speed_ex1": PD_speed_data_ex1,
#     "eyemovement_ex1": PD_eyemovement_data_ex1,
#     "pedal_ex2": PD_pedal_data_ex2,
#     "speed_ex2": PD_speed_data_ex2,
#     "eyemovement_ex2": PD_eyemovement_data_ex2,
#     # "pedal_ex3": PD_pedal_data_ex3,
#     # "speed_ex3": PD_speed_data_ex3,
#     # "eyemovement_ex3": PD_eyemovement_data_ex3
# }

# NC_data_dict = {
#     "pedal_ex1": NC_pedal_data_ex1,
#     "speed_ex1": NC_speed_data_ex1,
#     "eyemovement_ex1": NC_eyemovement_data_ex1,
#     "pedal_ex2": NC_pedal_data_ex2,
#     "speed_ex2": NC_speed_data_ex2,
#     "eyemovement_ex2": NC_eyemovement_data_ex2,
#     # "pedal_ex3": NC_pedal_data_ex3,
#     # "speed_ex3": NC_speed_data_ex3,
#     # "eyemovement_ex3": NC_eyemovement_data_ex3
# }

# person_num = 8
# for type in ["pedal", "speed", "eyemovement"]:
#     for ex in ["ex2"]:
#         for data_type in ["whole"]:
#             # 动态获取相应的数据集
#             big_df = PD_data_dict[type+"_"+ex]
            
#             # 根据person_id筛出当前这个人
#             df = big_df[big_df['person_id'] == person_num + 1].copy().reset_index(drop=True)

#             # 调用concat_df进行数据切片处理
#             df_subset = concat_df(df, "PD", person_num, data_type,ex)
            
#             # 构建保存文件的路径
#             output_dir = f"./sliced_data/PD/PD{person_num + 1}"
            
#             # 确保目标路径存在
#             os.makedirs(output_dir, exist_ok=True)
            
#             # 保存文件
#             file_path = f"{output_dir}/{data_type}_{type+"_"+ex}.csv"
#             df_subset.to_csv(file_path, index=False)
#             print(f"over {person_num + 1} - {type+"_"+ex} - {data_type}")

# %%
import os
import pandas as pd
from config.config_loader import load_config

CONFIG_DATA = load_config(os.path.join("config", "feature_engineering_config.json"))
NC_number = CONFIG_DATA["NC_number"]
PD_number = CONFIG_DATA["PD_number"]

# === 读取PD组 ===
PD_pedal_data_ex1 = pd.read_csv('data_pro1/PD_pedal_data_ex1.csv')
PD_speed_data_ex1 = pd.read_csv('data_pro1/PD_speed_data_ex1.csv')
PD_eyemovement_data_ex1 = pd.read_csv('data_pro1/PD_eyemovement_data_ex1.csv')

PD_pedal_data_ex2 = pd.read_csv('data_pro1/PD_pedal_data_ex2.csv')
PD_speed_data_ex2 = pd.read_csv('data_pro1/PD_speed_data_ex2.csv')
PD_eyemovement_data_ex2 = pd.read_csv('data_pro1/PD_eyemovement_data_ex2.csv')

# PD_pedal_data_ex3 = pd.read_csv('data_pro1/PD_pedal_data_ex3.csv')
# PD_speed_data_ex3 = pd.read_csv('data_pro1/PD_speed_data_ex3.csv')
# PD_eyemovement_data_ex3 = pd.read_csv('data_pro1/PD_eyemovement_data_ex3.csv')

# === 读取NC组 ===
NC_pedal_data_ex1 = pd.read_csv('data_pro1/NC_pedal_data_ex1.csv')
NC_speed_data_ex1 = pd.read_csv('data_pro1/NC_speed_data_ex1.csv')
NC_eyemovement_data_ex1 = pd.read_csv('data_pro1/NC_eyemovement_data_ex1.csv')

NC_pedal_data_ex2 = pd.read_csv('data_pro1/NC_pedal_data_ex2.csv')
NC_speed_data_ex2 = pd.read_csv('data_pro1/NC_speed_data_ex2.csv')
NC_eyemovement_data_ex2 = pd.read_csv('data_pro1/NC_eyemovement_data_ex2.csv')

# NC_pedal_data_ex3 = pd.read_csv('data_pro1/NC_pedal_data_ex3.csv')
# NC_speed_data_ex3 = pd.read_csv('data_pro1/NC_speed_data_ex3.csv')
# NC_eyemovement_data_ex3 = pd.read_csv('data_pro1/NC_eyemovement_data_ex3.csv')

PD_data_dict = {
    "pedal_ex1": PD_pedal_data_ex1,
    "speed_ex1": PD_speed_data_ex1,
    "eyemovement_ex1": PD_eyemovement_data_ex1,
    "pedal_ex2": PD_pedal_data_ex2,
    "speed_ex2": PD_speed_data_ex2,
    "eyemovement_ex2": PD_eyemovement_data_ex2,
    # "pedal_ex3": PD_pedal_data_ex3,
    # "speed_ex3": PD_speed_data_ex3,
    # "eyemovement_ex3": PD_eyemovement_data_ex3
}

NC_data_dict = {
    "pedal_ex1": NC_pedal_data_ex1,
    "speed_ex1": NC_speed_data_ex1,
    "eyemovement_ex1": NC_eyemovement_data_ex1,
    "pedal_ex2": NC_pedal_data_ex2,
    "speed_ex2": NC_speed_data_ex2,
    "eyemovement_ex2": NC_eyemovement_data_ex2,
    # "pedal_ex3": NC_pedal_data_ex3,
    # "speed_ex3": NC_speed_data_ex3,
    # "eyemovement_ex3": NC_eyemovement_data_ex3
}

#为PD的ex2的三个数据文件切片
for person_num in range(PD_number):  
    # 对每种数据类型进行处理
    for type in ["pedal", "speed", "eyemovement"]:
        for ex in ["ex1","ex2"]:
            for data_type in ["whole"]:
                # 动态获取相应的数据集
                big_df = PD_data_dict[type+"_"+ex]
                
                # 根据person_id筛出当前这个人
                df = big_df[big_df['person_id'] == person_num + 1].copy().reset_index(drop=True)

                # 调用concat_df进行数据切片处理
                df_subset = concat_df(df, "PD", person_num, data_type,ex)
                
                # 构建保存文件的路径
                output_dir = f"./sliced_data/PD/PD{person_num + 1}"
                
                # 确保目标路径存在
                os.makedirs(output_dir, exist_ok=True)
                
                # 保存文件
                file_path = f"{output_dir}/{data_type}_{type+"_"+ex}.csv"
                df_subset.to_csv(file_path, index=False)
                print(f"over {person_num + 1} - {type+"_"+ex} - {data_type}")


for person_num in range(NC_number):  
    # 对每种数据类型进行处理
    for type in ["pedal", "speed", "eyemovement"]:
        for ex in ["ex1","ex2"]:
            for data_type in ["whole"]:
                # 动态获取相应的数据集
                big_df = NC_data_dict[type+"_"+ex]
                
                # 根据person_id筛出当前这个人
                df = big_df[big_df['person_id'] == person_num + 1].copy().reset_index(drop=True)
                
                # 调用concat_df进行数据切片处理
                df_subset = concat_df(df, "NC", person_num, data_type,ex)
                
                # 构建保存文件的路径
                output_dir = f"./sliced_data/NC/NC{person_num + 1}"
                
                # 确保目标路径存在
                os.makedirs(output_dir, exist_ok=True)
                
                # 保存文件
                file_path = f"{output_dir}/{data_type}_{type+"_"+ex}.csv"
                df_subset.to_csv(file_path, index=False)
                print(f"over {person_num + 1} - {type+"_"+ex} - {data_type}")
# Out:
# Trying to slice:  2298 13267
# over 1 - pedal_ex1 - whole
# Trying to slice:  814 11035
# over 1 - pedal_ex2 - whole
# Trying to slice:  4051 16951
# over 1 - speed_ex1 - whole
# Trying to slice:  2501 14526
# over 1 - speed_ex2 - whole
# Trying to slice:  14827 76798
# over 1 - eyemovement_ex1 - whole
# Trying to slice:  5890 63730
# over 1 - eyemovement_ex2 - whole
# Trying to slice:  650 12850
# over 2 - pedal_ex1 - whole
# Trying to slice:  490 11839
# over 2 - pedal_ex2 - whole
# Trying to slice:  2251 16601
# over 2 - speed_ex1 - whole
# Trying to slice:  2126 15451
# over 2 - speed_ex2 - whole
# Trying to slice:  5635 74546
# over 2 - eyemovement_ex1 - whole
# Trying to slice:  5021 69009
# over 2 - eyemovement_ex2 - whole
# Trying to slice:  695 13057
# over 3 - pedal_ex1 - whole
# Trying to slice:  601 13048
# over 3 - pedal_ex2 - whole
# Trying to slice:  2026 16551
# over 3 - speed_ex1 - whole
# Trying to slice:  1901 16526
# over 3 - speed_ex2 - whole
# Trying to slice:  5161 74891
# over 3 - eyemovement_ex1 - whole
# Trying to slice:  4597 74807
# over 3 - eyemovement_ex2 - whole
# Trying to slice:  815 12589
# over 4 - pedal_ex1 - whole
# Trying to slice:  577 8878
# over 4 - pedal_ex2 - whole
# Trying to slice:  2626 16451
# over 4 - speed_ex1 - whole
# Trying to slice:  1951 11701
# over 4 - speed_ex2 - whole
# Trying to slice:  6962 73338
# over 4 - eyemovement_ex1 - whole
# Trying to slice:  4528 51353
# over 4 - eyemovement_ex2 - whole
# Trying to slice:  492 13039
# over 5 - pedal_ex1 - whole
# Trying to slice:  626 12848
# over 5 - pedal_ex2 - whole
# Trying to slice:  1776 16501
# over 5 - speed_ex1 - whole
# Trying to slice:  2076 16426
# over 5 - speed_ex2 - whole
# Trying to slice:  3911 74601
# over 5 - eyemovement_ex1 - whole
# Trying to slice:  5260 74151
# over 5 - eyemovement_ex2 - whole
# Trying to slice:  1038 13045
# over 6 - pedal_ex1 - whole
# Trying to slice:  868 12844
# over 6 - pedal_ex2 - whole
# Trying to slice:  2451 16551
# over 6 - speed_ex1 - whole
# Trying to slice:  2426 16501
# over 6 - speed_ex2 - whole
# Trying to slice:  7038 74729
# over 6 - eyemovement_ex1 - whole
# Trying to slice:  6593 74163
# over 6 - eyemovement_ex2 - whole
# Trying to slice:  1000 12723
# over 7 - pedal_ex1 - whole
# Trying to slice:  1471 12691
# over 7 - pedal_ex2 - whole
# Trying to slice:  2726 16501
# over 7 - speed_ex1 - whole
# Trying to slice:  3301 16501
# over 7 - speed_ex2 - whole
# Trying to slice:  7540 73670
# over 7 - eyemovement_ex1 - whole
# Trying to slice:  9902 73275
# over 7 - eyemovement_ex2 - whole
# Trying to slice:  597 13236
# over 8 - pedal_ex1 - whole
# Trying to slice:  629 12685
# over 8 - pedal_ex2 - whole
# Trying to slice:  2351 17201
# over 8 - speed_ex1 - whole
# Trying to slice:  2076 16251
# over 8 - speed_ex2 - whole
# Trying to slice:  6565 77859
# over 8 - eyemovement_ex1 - whole
# Trying to slice:  4902 72953
# over 8 - eyemovement_ex2 - whole
# Trying to slice:  None None
# over 9 - pedal_ex1 - whole
# Trying to slice:  1083 10999
# over 9 - pedal_ex2 - whole
# Trying to slice:  None None
# over 9 - speed_ex1 - whole
# Trying to slice:  4001 15651
# over 9 - speed_ex2 - whole
# Trying to slice:  None None
# over 9 - eyemovement_ex1 - whole
# Trying to slice:  7916 63880
# over 9 - eyemovement_ex2 - whole
# Trying to slice:  1914 16827
# over 10 - pedal_ex1 - whole
# Trying to slice:  1285 21726
# over 10 - pedal_ex2 - whole
# Trying to slice:  5051 22576
# over 10 - speed_ex1 - whole
# Trying to slice:  4551 28576
# over 10 - speed_ex2 - whole
# Trying to slice:  14512 98685
# over 10 - eyemovement_ex1 - whole
# Trying to slice:  16026 131375
# over 10 - eyemovement_ex2 - whole
# Trying to slice:  791 16944
# over 11 - pedal_ex1 - whole
# Trying to slice:  727 16728
# over 11 - pedal_ex2 - whole
# Trying to slice:  3176 22151
# over 11 - speed_ex1 - whole
# Trying to slice:  3601 22426
# over 11 - speed_ex2 - whole
# Trying to slice:  9592 100695
# over 11 - eyemovement_ex1 - whole
# Trying to slice:  8448 98820
# over 11 - eyemovement_ex2 - whole
# Trying to slice:  396 18948
# over 12 - pedal_ex1 - whole
# Trying to slice:  839 15681
# over 12 - pedal_ex2 - whole
# Trying to slice:  2876 24676
# over 12 - speed_ex1 - whole
# Trying to slice:  5976 23426
# over 12 - speed_ex2 - whole
# Trying to slice:  6440 111095
# over 12 - eyemovement_ex1 - whole
# Trying to slice:  8633 92440
# over 12 - eyemovement_ex2 - whole
# Trying to slice:  1126 19320
# over 13 - pedal_ex1 - whole
# Trying to slice:  594 19475
# over 13 - pedal_ex2 - whole
# Trying to slice:  7426 28801
# over 13 - speed_ex1 - whole
# Trying to slice:  2826 25001
# over 13 - speed_ex2 - whole
# Trying to slice:  13890 116509
# over 13 - eyemovement_ex1 - whole
# Trying to slice:  6817 113276
# over 13 - eyemovement_ex2 - whole
# Trying to slice:  1102 17862
# over 14 - pedal_ex1 - whole
# Trying to slice:  1093 17608
# over 14 - pedal_ex2 - whole
# Trying to slice:  4376 24101
# over 14 - speed_ex1 - whole
# Trying to slice:  3601 23026
# over 14 - speed_ex2 - whole
# Trying to slice:  8885 103579
# over 14 - eyemovement_ex1 - whole
# Trying to slice:  10332 103593
# over 14 - eyemovement_ex2 - whole
# Trying to slice:  2109 18009
# over 15 - pedal_ex1 - whole
# Trying to slice:  1269 18081
# over 15 - pedal_ex2 - whole
# Trying to slice:  5751 24451
# over 15 - speed_ex1 - whole
# Trying to slice:  3701 23451
# over 15 - speed_ex2 - whole
# Trying to slice:  20861 110638
# over 15 - eyemovement_ex1 - whole
# Trying to slice:  9467 104290
# over 15 - eyemovement_ex2 - whole
# Trying to slice:  1442 16078
# over 16 - pedal_ex1 - whole
# Trying to slice:  1890 18384
# over 16 - pedal_ex2 - whole
# Trying to slice:  3876 21076
# over 16 - speed_ex1 - whole
# Trying to slice:  5626 25026
# over 16 - speed_ex2 - whole
# Trying to slice:  12243 94812
# over 16 - eyemovement_ex1 - whole
# Trying to slice:  15702 108841
# over 16 - eyemovement_ex2 - whole
# Trying to slice:  677 10757
# over 17 - pedal_ex1 - whole
# Trying to slice:  672 10414
# over 17 - pedal_ex2 - whole
# Trying to slice:  5476 17326
# over 17 - speed_ex1 - whole
# Trying to slice:  4476 15926
# over 17 - speed_ex2 - whole
# Trying to slice:  6881 63791
# over 17 - eyemovement_ex1 - whole
# Trying to slice:  10747 65741
# over 17 - eyemovement_ex2 - whole
# Trying to slice:  1372 15658
# over 18 - pedal_ex1 - whole
# Trying to slice:  1401 18386
# over 18 - pedal_ex2 - whole
# Trying to slice:  6876 23701
# over 18 - speed_ex1 - whole
# Trying to slice:  4101 24076
# over 18 - speed_ex2 - whole
# Trying to slice:  12944 93759
# over 18 - eyemovement_ex1 - whole
# Trying to slice:  13081 109054
# over 18 - eyemovement_ex2 - whole
# Trying to slice:  2206 20274
# over 19 - pedal_ex1 - whole
# Trying to slice:  1466 16748
# over 19 - pedal_ex2 - whole
# Trying to slice:  4376 25551
# over 19 - speed_ex1 - whole
# Trying to slice:  4801 22701
# over 19 - speed_ex2 - whole
# Trying to slice:  16107 117769
# over 19 - eyemovement_ex1 - whole
# Trying to slice:  11348 97281
# over 19 - eyemovement_ex2 - whole
# Trying to slice:  590 9294
# over 20 - pedal_ex1 - whole
# Trying to slice:  1158 18686
# over 20 - pedal_ex2 - whole
# Trying to slice:  7626 17876
# over 20 - speed_ex1 - whole
# Trying to slice:  3751 24351
# over 20 - speed_ex2 - whole
# Trying to slice:  8961 58170
# over 20 - eyemovement_ex1 - whole
# Trying to slice:  10034 108928
# over 20 - eyemovement_ex2 - whole
# Trying to slice:  868 16993
# over 21 - pedal_ex1 - whole
# Trying to slice:  769 17357
# over 21 - pedal_ex2 - whole
# Trying to slice:  6876 25826
# over 21 - speed_ex1 - whole
# Trying to slice:  4401 23901
# over 21 - speed_ex2 - whole
# Trying to slice:  8597 99797
# over 21 - eyemovement_ex1 - whole
# Trying to slice:  6517 100140
# over 21 - eyemovement_ex2 - whole
# Trying to slice:  987 18053
# over 22 - pedal_ex1 - whole
# Trying to slice:  809 16670
# over 22 - pedal_ex2 - whole
# Trying to slice:  2901 22951
# over 22 - speed_ex1 - whole
# Trying to slice:  2901 21551
# over 22 - speed_ex2 - whole
# Trying to slice:  6759 103012
# over 22 - eyemovement_ex1 - whole
# Trying to slice:  7572 97102
# over 22 - eyemovement_ex2 - whole
# Trying to slice:  919 16387
# over 23 - pedal_ex1 - whole
# Trying to slice:  1546 18119
# over 23 - pedal_ex2 - whole
# Trying to slice:  3751 21851
# over 23 - speed_ex1 - whole
# Trying to slice:  3601 23026
# over 23 - speed_ex2 - whole
# Trying to slice:  10401 97318
# over 23 - eyemovement_ex1 - whole
# Trying to slice:  10272 103559
# over 23 - eyemovement_ex2 - whole
# Trying to slice:  2893 20427
# over 24 - pedal_ex1 - whole
# Trying to slice:  939 17652
# over 24 - pedal_ex2 - whole
# Trying to slice:  5676 26201
# over 24 - speed_ex1 - whole
# Trying to slice:  3751 23301
# over 24 - speed_ex2 - whole
# Trying to slice:  19321 117853
# over 24 - eyemovement_ex1 - whole
# Trying to slice:  9826 103681
# over 24 - eyemovement_ex2 - whole
# Trying to slice:  724 17672
# over 25 - pedal_ex1 - whole
# Trying to slice:  441 17126
# over 25 - pedal_ex2 - whole
# Trying to slice:  2576 22451
# over 25 - speed_ex1 - whole
# Trying to slice:  2201 21801
# over 25 - speed_ex2 - whole
# Trying to slice:  6745 102202
# over 25 - eyemovement_ex1 - whole
# Trying to slice:  4353 98444
# over 25 - eyemovement_ex2 - whole
# Trying to slice:  619 17034
# over 26 - pedal_ex1 - whole
# Trying to slice:  780 17224
# over 26 - pedal_ex2 - whole
# Trying to slice:  3851 23176
# over 26 - speed_ex1 - whole
# Trying to slice:  3151 22451
# over 26 - speed_ex2 - whole
# Trying to slice:  8168 100981
# over 26 - eyemovement_ex1 - whole
# Trying to slice:  6114 98796
# over 26 - eyemovement_ex2 - whole
# Trying to slice:  580 17765
# over 27 - pedal_ex1 - whole
# Trying to slice:  658 18256
# over 27 - pedal_ex2 - whole
# Trying to slice:  3051 23251
# over 27 - speed_ex1 - whole
# Trying to slice:  3351 24026
# over 27 - speed_ex2 - whole
# Trying to slice:  5301 102273
# over 27 - eyemovement_ex1 - whole
# Trying to slice:  5761 105014
# over 27 - eyemovement_ex2 - whole
# Trying to slice:  1756 12483
# over 1 - pedal_ex1 - whole
# Trying to slice:  707 12136
# over 1 - pedal_ex2 - whole
# Trying to slice:  3826 16426
# over 1 - speed_ex1 - whole
# Trying to slice:  2451 15876
# over 1 - speed_ex2 - whole
# Trying to slice:  12778 73265
# over 1 - eyemovement_ex1 - whole
# Trying to slice:  5283 69734
# over 1 - eyemovement_ex2 - whole
# Trying to slice:  1086 12875
# over 2 - pedal_ex1 - whole
# Trying to slice:  1320 12253
# over 2 - pedal_ex2 - whole
# Trying to slice:  2776 16626
# over 2 - speed_ex1 - whole
# Trying to slice:  4401 17251
# over 2 - speed_ex2 - whole
# Trying to slice:  7454 73942
# over 2 - eyemovement_ex1 - whole
# Trying to slice:  8945 70638
# over 2 - eyemovement_ex2 - whole
# Trying to slice:  737 12271
# over 3 - pedal_ex1 - whole
# Trying to slice:  404 8875
# over 3 - pedal_ex2 - whole
# Trying to slice:  2076 15626
# over 3 - speed_ex1 - whole
# Trying to slice:  4176 14126
# over 3 - speed_ex2 - whole
# Trying to slice:  5294 70342
# over 3 - eyemovement_ex1 - whole
# Trying to slice:  4456 52222
# over 3 - eyemovement_ex2 - whole
# Trying to slice:  1463 10866
# over 4 - pedal_ex1 - whole
# Trying to slice:  1029 10906
# over 4 - pedal_ex2 - whole
# Trying to slice:  4501 15551
# over 4 - speed_ex1 - whole
# Trying to slice:  3026 14626
# over 4 - speed_ex2 - whole
# Trying to slice:  12313 65361
# over 4 - eyemovement_ex1 - whole
# Trying to slice:  7671 63362
# over 4 - eyemovement_ex2 - whole
# Trying to slice:  589 13478
# over 5 - pedal_ex1 - whole
# Trying to slice:  815 14059
# over 5 - pedal_ex2 - whole
# Trying to slice:  2076 17226
# over 5 - speed_ex1 - whole
# Trying to slice:  2451 18001
# over 5 - speed_ex2 - whole
# Trying to slice:  4809 77543
# over 5 - eyemovement_ex1 - whole
# Trying to slice:  6429 81087
# over 5 - eyemovement_ex2 - whole
# Trying to slice:  729 13238
# over 6 - pedal_ex1 - whole
# Trying to slice:  143 13361
# over 6 - pedal_ex2 - whole
# Trying to slice:  2701 17401
# over 6 - speed_ex1 - whole
# Trying to slice:  1826 17351
# over 6 - speed_ex2 - whole
# Trying to slice:  5836 76404
# over 6 - eyemovement_ex1 - whole
# Trying to slice:  4026 78558
# over 6 - eyemovement_ex2 - whole
# Trying to slice:  1113 12885
# over 7 - pedal_ex1 - whole
# Trying to slice:  460 9862
# over 7 - pedal_ex2 - whole
# Trying to slice:  3301 17076
# over 7 - speed_ex1 - whole
# Trying to slice:  1826 12826
# over 7 - speed_ex2 - whole
# Trying to slice:  8191 74343
# over 7 - eyemovement_ex1 - whole
# Trying to slice:  4118 56938
# over 7 - eyemovement_ex2 - whole
# Trying to slice:  785 11404
# over 8 - pedal_ex1 - whole
# Trying to slice:  990 10518
# over 8 - pedal_ex2 - whole
# Trying to slice:  2526 14951
# over 8 - speed_ex1 - whole
# Trying to slice:  2501 13651
# over 8 - speed_ex2 - whole
# Trying to slice:  7409 67129
# over 8 - eyemovement_ex1 - whole
# Trying to slice:  7116 60665
# over 8 - eyemovement_ex2 - whole
# Trying to slice:  1122 13742
# over 9 - pedal_ex1 - whole
# Trying to slice:  903 13679
# over 9 - pedal_ex2 - whole
# Trying to slice:  3576 18326
# over 9 - speed_ex1 - whole
# Trying to slice:  2426 17376
# over 9 - speed_ex2 - whole
# Trying to slice:  12365 83179
# over 9 - eyemovement_ex1 - whole
# Trying to slice:  6671 78460
# over 9 - eyemovement_ex2 - whole
# Trying to slice:  1222 12189
# over 10 - pedal_ex1 - whole
# Trying to slice:  1359 11070
# over 10 - pedal_ex2 - whole
# Trying to slice:  3901 16726
# over 10 - speed_ex1 - whole
# Trying to slice:  5051 16401
# over 10 - speed_ex2 - whole
# Trying to slice:  8694 70263
# over 10 - eyemovement_ex1 - whole
# Trying to slice:  9889 64378
# over 10 - eyemovement_ex2 - whole
# Trying to slice:  874 14581
# over 11 - pedal_ex1 - whole
# Trying to slice:  663 10727
# over 11 - pedal_ex2 - whole
# Trying to slice:  2526 18551
# over 11 - speed_ex1 - whole
# Trying to slice:  3276 15026
# over 11 - speed_ex2 - whole
# Trying to slice:  7340 84285
# over 11 - eyemovement_ex1 - whole
# Trying to slice:  5703 62124
# over 11 - eyemovement_ex2 - whole
# Trying to slice:  200 12380
# over 12 - pedal_ex1 - whole
# Trying to slice:  382 12104
# over 12 - pedal_ex2 - whole
# Trying to slice:  1776 16051
# over 12 - speed_ex1 - whole
# Trying to slice:  1751 15476
# over 12 - speed_ex2 - whole
# Trying to slice:  3936 72481
# over 12 - eyemovement_ex1 - whole
# Trying to slice:  3790 69685
# over 12 - eyemovement_ex2 - whole
# Trying to slice:  782 14600
# over 13 - pedal_ex1 - whole
# Trying to slice:  424 13147
# over 13 - pedal_ex2 - whole
# Trying to slice:  2376 18551
# over 13 - speed_ex1 - whole
# Trying to slice:  2326 17226
# over 13 - speed_ex2 - whole
# Trying to slice:  6365 84018
# over 13 - eyemovement_ex1 - whole
# Trying to slice:  6590 78131
# over 13 - eyemovement_ex2 - whole
# Trying to slice:  862 19439
# over 14 - pedal_ex1 - whole
# Trying to slice:  866 17025
# over 14 - pedal_ex2 - whole
# Trying to slice:  3676 25501
# over 14 - speed_ex1 - whole
# Trying to slice:  3726 22726
# over 14 - speed_ex2 - whole
# Trying to slice:  7580 112363
# over 14 - eyemovement_ex1 - whole
# Trying to slice:  6515 97727
# over 14 - eyemovement_ex2 - whole
# Trying to slice:  755 17969
# over 15 - pedal_ex1 - whole
# Trying to slice:  835 16454
# over 15 - pedal_ex2 - whole
# Trying to slice:  2601 22826
# over 15 - speed_ex1 - whole
# Trying to slice:  4476 22851
# over 15 - speed_ex2 - whole
# Trying to slice:  6302 103398
# over 15 - eyemovement_ex1 - whole
# Trying to slice:  7603 95814
# over 15 - eyemovement_ex2 - whole
# Trying to slice:  1006 17652
# over 16 - pedal_ex1 - whole
# Trying to slice:  1055 17719
# over 16 - pedal_ex2 - whole
# Trying to slice:  3651 23226
# over 16 - speed_ex1 - whole
# Trying to slice:  3951 23526
# over 16 - speed_ex2 - whole
# Trying to slice:  7810 101785
# over 16 - eyemovement_ex1 - whole
# Trying to slice:  7646 101619
# over 16 - eyemovement_ex2 - whole
# Trying to slice:  1785 17721
# over 17 - pedal_ex1 - whole
# Trying to slice:  388 16376
# over 17 - pedal_ex2 - whole
# Trying to slice:  4301 23026
# over 17 - speed_ex1 - whole
# Trying to slice:  2226 21026
# over 17 - speed_ex2 - whole
# Trying to slice:  15301 105196
# over 17 - eyemovement_ex1 - whole
# Trying to slice:  4406 94656
# over 17 - eyemovement_ex2 - whole
# Trying to slice:  797 18148
# over 18 - pedal_ex1 - whole
# Trying to slice:  1051 18018
# over 18 - pedal_ex2 - whole
# Trying to slice:  2651 23051
# over 18 - speed_ex1 - whole
# Trying to slice:  3051 22976
# over 18 - speed_ex2 - whole
# Trying to slice:  6209 104140
# over 18 - eyemovement_ex1 - whole
# Trying to slice:  7649 103310
# over 18 - eyemovement_ex2 - whole
# Trying to slice:  1507 20255
# over 19 - pedal_ex1 - whole
# Trying to slice:  997 18055
# over 19 - pedal_ex2 - whole
# Trying to slice:  3926 25951
# over 19 - speed_ex1 - whole
# Trying to slice:  4001 24051
# over 19 - speed_ex2 - whole
# Trying to slice:  12652 118397
# over 19 - eyemovement_ex1 - whole
# Trying to slice:  7877 104133
# over 19 - eyemovement_ex2 - whole
# Trying to slice:  711 18580
# over 20 - pedal_ex1 - whole
# Trying to slice:  338 17357
# over 20 - pedal_ex2 - whole
# Trying to slice:  3026 24051
# over 20 - speed_ex1 - whole
# Trying to slice:  2301 22301
# over 20 - speed_ex2 - whole
# Trying to slice:  6132 107066
# over 20 - eyemovement_ex1 - whole
# Trying to slice:  3763 99777
# over 20 - eyemovement_ex2 - whole
# Trying to slice:  3629 18845
# over 21 - pedal_ex1 - whole
# Trying to slice:  680 17992
# over 21 - pedal_ex2 - whole
# Trying to slice:  6101 23976
# over 21 - speed_ex1 - whole
# Trying to slice:  3526 23876
# over 21 - speed_ex2 - whole
# Trying to slice:  22204 108019
# over 21 - eyemovement_ex1 - whole
# Trying to slice:  8501 105283
# over 21 - eyemovement_ex2 - whole
# Trying to slice:  656 17927
# over 22 - pedal_ex1 - whole
# Trying to slice:  334 15025
# over 22 - pedal_ex2 - whole
# Trying to slice:  2751 23051
# over 22 - speed_ex1 - whole
# Trying to slice:  6651 23926
# over 22 - speed_ex2 - whole
# Trying to slice:  5504 102962
# over 22 - eyemovement_ex1 - whole
# Trying to slice:  3606 86536
# over 22 - eyemovement_ex2 - whole
# Trying to slice:  721 19023
# over 23 - pedal_ex1 - whole
# Trying to slice:  1215 17624
# over 23 - pedal_ex2 - whole
# Trying to slice:  2301 23801
# over 23 - speed_ex1 - whole
# Trying to slice:  4176 23476
# over 23 - speed_ex2 - whole
# Trying to slice:  5562 108984
# over 23 - eyemovement_ex1 - whole
# Trying to slice:  8408 101173
# over 23 - eyemovement_ex2 - whole
# Trying to slice:  690 18687
# over 24 - pedal_ex1 - whole
# Trying to slice:  816 18475
# over 24 - pedal_ex2 - whole
# Trying to slice:  4926 26076
# over 24 - speed_ex1 - whole
# Trying to slice:  2426 23176
# over 24 - speed_ex2 - whole
# Trying to slice:  5819 107445
# over 24 - eyemovement_ex1 - whole
# Trying to slice:  6088 105719
# over 24 - eyemovement_ex2 - whole
# Trying to slice:  1557 19014
# over 25 - pedal_ex1 - whole
# Trying to slice:  38 1805
# Trying to slice:  1890 8821
# Trying to slice:  8906 14494
# over 25 - pedal_ex2 - whole
# Trying to slice:  3501 24051
# over 25 - speed_ex1 - whole
# Trying to slice:  2126 4201
# Trying to slice:  4301 12451
# Trying to slice:  12551 19126
# over 25 - speed_ex2 - whole
# Trying to slice:  11160 109825
# over 25 - eyemovement_ex1 - whole
# Trying to slice:  2427 12389
# Trying to slice:  12869 51995
# Trying to slice:  52475 84039
# over 25 - eyemovement_ex2 - whole
# Trying to slice:  915 18530
# over 26 - pedal_ex1 - whole
# Trying to slice:  566 17716
# over 26 - pedal_ex2 - whole
# Trying to slice:  5051 25751
# over 26 - speed_ex1 - whole
# Trying to slice:  2651 22801
# over 26 - speed_ex2 - whole
# Trying to slice:  9867 109255
# over 26 - eyemovement_ex1 - whole
# Trying to slice:  4975 101737
# over 26 - eyemovement_ex2 - whole
# Trying to slice:  541 21300
# over 27 - pedal_ex1 - whole
# Trying to slice:  730 18077
# over 27 - pedal_ex2 - whole
# Trying to slice:  2326 26726
# over 27 - speed_ex1 - whole
# Trying to slice:  3226 23626
# over 27 - speed_ex2 - whole
# Trying to slice:  5036 122204
# over 27 - eyemovement_ex1 - whole
# Trying to slice:  7673 105610
# over 27 - eyemovement_ex2 - whole
# Trying to slice:  3669 18226
# over 28 - pedal_ex1 - whole
# Trying to slice:  660 19362
# over 28 - pedal_ex2 - whole
# Trying to slice:  6101 23226
# over 28 - speed_ex1 - whole
# Trying to slice:  2376 24351
# over 28 - speed_ex2 - whole
# Trying to slice:  22356 104572
# over 28 - eyemovement_ex1 - whole
# Trying to slice:  6016 111510
# over 28 - eyemovement_ex2 - whole
# Trying to slice:  709 18459
# over 29 - pedal_ex1 - whole
# Trying to slice:  702 16614
# over 29 - pedal_ex2 - whole
# Trying to slice:  2301 23151
# over 29 - speed_ex1 - whole
# Trying to slice:  3276 21976
# over 29 - speed_ex2 - whole
# Trying to slice:  5697 105856
# over 29 - eyemovement_ex1 - whole
# Trying to slice:  8188 97988
# over 29 - eyemovement_ex2 - whole
# Trying to slice:  1159 17120
# over 30 - pedal_ex1 - whole
# Trying to slice:  1402 17876
# over 30 - pedal_ex2 - whole
# Trying to slice:  4601 23351
# over 30 - speed_ex1 - whole
# Trying to slice:  3526 22901
# over 30 - speed_ex2 - whole
# Trying to slice:  8758 98782
# over 30 - eyemovement_ex1 - whole
# Trying to slice:  9647 102671
# over 30 - eyemovement_ex2 - whole
# Trying to slice:  684 17923
# over 31 - pedal_ex1 - whole
# Trying to slice:  331 15140
# over 31 - pedal_ex2 - whole
# Trying to slice:  3026 23351
# over 31 - speed_ex1 - whole
# Trying to slice:  3801 21201
# over 31 - speed_ex2 - whole
# Trying to slice:  5244 102821
# over 31 - eyemovement_ex1 - whole
# Trying to slice:  4210 87743
# over 31 - eyemovement_ex2 - whole
